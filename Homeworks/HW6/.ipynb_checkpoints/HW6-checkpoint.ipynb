# %%
import re
from math import log

# %%
def bigram(x):
    for i in range(len(x)-1):
        yield x[i] + '_' + x[i+1]

# %% [markdown]
# ## Read

# %%
# считываем датасет
en_articles_part = sc.textFile("/data/wiki/en_articles_part")

# %%
# делаем из en_articles_part датасет "ключ-значение"
splitted_articles = en_articles_part.map(lambda x: (x.split('\t')[0], x.split('\t')[1]))

# %%
# считываем стоп-слова
stop_words = sc.textFile("/data/wiki/stop_words_en-xpo6.txt")

# %%
stop_words = stop_words.collect()

# %%
stop_words[:5]
# Out:
# [u'a', u'about', u'above', u'across', u'after']

# %% [markdown]
# ## Задача #1: народные биграммы.

# %%
# оставляем в текстах статей только буквы
cleaned_articles = splitted_articles.map(lambda x: re.sub('[^a-z0-9 ]', '', x[1].lower()))

# %%
# делаем списки из слов (делим по пробелам)
articles_to_list = cleaned_articles.map(lambda x: [word.strip() for word in x.split(' ')])\
                                   .map(lambda x: [word for word in x if word])

# %%
# делаем биграммы
bigrams = articles_to_list.map(lambda x: list(bigram(x)))

# %%
bigrams.take(5)
# Out:
# [[u'anarchism_anarchism',
#   u'anarchism_is',
#   u'is_often',
#   u'often_defined',
#   u'defined_as',
#   u'as_a',
#   u'a_political',
#   u'political_philosophy',
#   u'philosophy_which',
#   u'which_holds',
#   u'holds_the',
#   u'the_state',
#   u'state_to',
#   u'to_be',
#   u'be_undesirable',
#   u'undesirable_unnecessary',
#   u'unnecessary_or',
#   u'or_harmful',
#   u'harmful_the',
#   u'the_following',
#   u'following_sources',
#   u'sources_cite',
#   u'cite_anarchism',
#   u'anarchism_as',
#   u'as_a',
#   u'a_political',
#   u'political_philosophy',
#   u'philosophy_slevin',
#   u'slevin_carl',
#   u'carl_anarchism',
#   u'anarchism_the',
#   u'the_concise',
#   u'concise_oxford',
#   u'oxford_dictionary',
#   u'dictionary_of',
#   u'of_politics',
#   u'politics_ed',
#   u'ed_iain',
#   u'iain_mclean',
#   u'mclean_and',
#   u'and_alistair',
#   u'alistair_mcmillan',
#   u'mcmillan_oxford',
#   u'oxford_university',
#   u'university_press',
#   u'press_2003',
#   u'2003_however',
#   u'however_others',
#   u'others_argue',
#   u'argue_that',
#   u'that_while',
#   u'while_antistatism',
#   u'antistatism_is',
#   u'is_central',
#   u'central_it',
#   u'it_is',
#   u'is_inadequate',
#   u'inadequate_to',
#   u'to_define',
#   u'define_anarchism',
#   u'anarchism_therefore',
#   u'therefore_they',
#   u'they_argue',
#   u'argue_instead',
#   u'instead_that',
#   u'that_anarchism',
#   u'anarchism_entails',
#   u'entails_opposing',
#   u'opposing_authority',
#   u'authority_or',
#   u'or_hierarchical',
#   u'hierarchical_organization',
#   u'organization_in',
#   u'in_the',
#   u'the_conduct',
#   u'conduct_of',
#   u'of_human',
#   u'human_relations',
#   u'relations_including',
#   u'including_but',
#   u'but_not',
#   u'not_only',
#   u'only_the',
#   u'the_state',
#   u'state_system',
#   u'system_proponents',
#   u'proponents_of',
#   u'of_anarchism',
#   u'anarchism_known',
#   u'known_as',
#   u'as_anarchists',
#   u'anarchists_advocate',
#   u'advocate_stateless',
#   u'stateless_societies',
#   u'societies_based',
#   u'based_on',
#   u'on_nonhierarchical',
#   u'nonhierarchical_free',
#   u'free_associations',
#   u'associations_as',
#   u'as_a',
#   u'a_subtle',
#   u'subtle_and',
#   u'and_antidogmatic',
#   u'antidogmatic_philosophy',
#   u'philosophy_anarchism',
#   u'anarchism_draws',
#   u'draws_on',
#   u'on_many',
#   u'many_currents',
#   u'currents_of',
#   u'of_thought',
#   u'thought_and',
#   u'and_strategy',
#   u'strategy_anarchism',
#   u'anarchism_does',
#   u'does_not',
#   u'not_offer',
#   u'offer_a',
#   u'a_fixed',
#   u'fixed_body',
#   u'body_of',
#   u'of_doctrine',
#   u'doctrine_from',
#   u'from_a',
#   u'a_single',
#   u'single_particular',
#   u'particular_world',
#   u'world_view',
#   u'view_instead',
#   u'instead_fluxing',
#   u'fluxing_and',
#   u'and_flowing',
#   u'flowing_as',
#   u'as_a',
#   u'a_philosophy',
#   u'philosophy_there',
#   u'there_are',
#   u'are_many',
#   u'many_types',
#   u'types_and',
#   u'and_traditions',
#   u'traditions_of',
#   u'of_anarchism',
#   u'anarchism_not',
#   u'not_all',
#   u'all_of',
#   u'of_which',
#   u'which_are',
#   u'are_mutually',
#   u'mutually_exclusive',
#   u'exclusive_anarchist',
#   u'anarchist_schools',
#   u'schools_of',
#   u'of_thought',
#   u'thought_can',
#   u'can_differ',
#   u'differ_fundamentally',
#   u'fundamentally_supporting',
#   u'supporting_anything',
#   u'anything_from',
#   u'from_extreme',
#   u'extreme_individualism',
#   u'individualism_to',
#   u'to_complete',
#   u'complete_collectivism',
#   u'collectivism_strains',
#   u'strains_of',
#   u'of_anarchism',
#   u'anarchism_have',
#   u'have_often',
#   u'often_been',
#   u'been_divided',
#   u'divided_into',
#   u'into_the',
#   u'the_categories',
#   u'categories_of',
#   u'of_social',
#   u'social_and',
#   u'and_individualist',
#   u'individualist_anarchism',
#   u'anarchism_or',
#   u'or_similar',
#   u'similar_dual',
#   u'dual_classifications',
#   u'classifications_ostergaard',
#   u'ostergaard_geoffrey',
#   u'geoffrey_anarchism',
#   u'anarchism_the',
#   u'the_blackwell',
#   u'blackwell_dictionary',
#   u'dictionary_of',
#   u'of_modern',
#   u'modern_social',
#   u'social_thought',
#   u'thought_blackwell',
#   u'blackwell_publishing',
#   u'publishing_p',
#   u'p_14',
#   u'14_anarchism',
#   u'anarchism_is',
#   u'is_often',
#   u'often_considered',
#   u'considered_a',
#   u'a_radical',
#   u'radical_leftwing',
#   u'leftwing_ideology',
#   u'ideology_and',
#   u'and_much',
#   u'much_of',
#   u'of_anarchist',
#   u'anarchist_economics',
#   u'economics_and',
#   u'and_anarchist',
#   u'anarchist_legal',
#   u'legal_philosophy',
#   u'philosophy_reflect',
#   u'reflect_antiauthoritarian',
#   u'antiauthoritarian_interpretations',
#   u'interpretations_of',
#   u'of_communism',
#   u'communism_collectivism',
#   u'collectivism_syndicalism',
#   u'syndicalism_mutualism',
#   u'mutualism_or',
#   u'or_participatory',
#   u'participatory_economics',
#   u'economics_anarchism',
#   u'anarchism_as',
#   u'as_a',
#   u'a_mass',
#   u'mass_social',
#   u'social_movement',
#   u'movement_has',
#   u'has_regularly',
#   u'regularly_endured',
#   u'endured_fluctuations',
#   u'fluctuations_in',
#   u'in_popularity',
#   u'popularity_the',
#   u'the_central',
#   u'central_tendency',
#   u'tendency_of',
#   u'of_anarchism',
#   u'anarchism_as',
#   u'as_a',
#   u'a_social',
#   u'social_movement',
#   u'movement_has',
#   u'has_been',
#   u'been_represented',
#   u'represented_by',
#   u'by_anarchocommunism',
#   u'anarchocommunism_and',
#   u'and_anarchosyndicalism',
#   u'anarchosyndicalism_with',
#   u'with_individualist',
#   u'individualist_anarchism',
#   u'anarchism_being',
#   u'being_primarily',
#   u'primarily_a',
#   u'a_literary',
#   u'literary_phenomenon',
#   u'phenomenon_which',
#   u'which_nevertheless',
#   u'nevertheless_did',
#   u'did_have',
#   u'have_an',
#   u'an_impact',
#   u'impact_on',
#   u'on_the',
#   u'the_bigger',
#   u'bigger_currents',
#   u'currents_and',
#   u'and_individualists',
#   u'individualists_have',
#   u'have_also',
#   u'also_participated',
#   u'participated_in',
#   u'in_large',
#   u'large_anarchist',
#   u'anarchist_organizations',
#   u'organizations_many',
#   u'many_anarchists',
#   u'anarchists_oppose',
#   u'oppose_all',
#   u'all_forms',
#   u'forms_of',
#   u'of_aggression',
#   u'aggression_supporting',
#   u'supporting_selfdefense',
#   u'selfdefense_or',
#   u'or_nonviolence',
#   u'nonviolence_anarchopacifism',
#   u'anarchopacifism_george',
#   u'george_woodcock',
#   u'woodcock_anarchism',
#   u'anarchism_a',
#   u'a_history',
#   u'history_of',
#   u'of_libertarian',
#   u'libertarian_ideas',
#   u'ideas_and',
#   u'and_movements',
#   u'movements_1962',
#   u'1962_while',
#   u'while_others',
#   u'others_have',
#   u'have_supported',
#   u'supported_the',
#   u'the_use',
#   u'use_of',
#   u'of_some',
#   u'some_coercive',
#   u'coercive_measures',
#   u'measures_including',
#   u'including_violent',
#   u'violent_revolution',
#   u'revolution_and',
#   u'and_propaganda',
#   u'propaganda_of',
#   u'of_the',
#   u'the_deed',
#   u'deed_on',
#   u'on_the',
#   u'the_path',
#   u'path_to',
#   u'to_an',
#   u'an_anarchist',
#   u'anarchist_society',
#   u'society_etymology',
#   u'etymology_and',
#   u'and_terminology',
#   u'terminology_the',
#   u'the_term',
#   u'term_derives',
#   u'derives_from',
#   u'from_the',
#   u'the_ancient',
#   u'ancient_greek',
#   u'greek_anarchos',
#   u'anarchos_meaning',
#   u'meaning_without',
#   u'without_rulers',
#   u'rulers_from',
#   u'from_the',
#   u'the_prefix',
#   u'prefix_an',
#   u'an_without',
#   u'without_arkhos',
#   u'arkhos_leader',
#   u'leader_from',
#   u'from_arkh',
#   u'arkh_authority',
#   u'authority_sovereignty',
#   u'sovereignty_realm',
#   u'realm_magistracy',
#   u'magistracy_ismos',
#   u'ismos_from',
#   u'from_the',
#   u'the_suffix',
#   u'suffix_izein',
#   u'izein_izing',
#   u'izing_anarchists',
#   u'anarchists_was',
#   u'was_the',
#   u'the_term',
#   u'term_adopted',
#   u'adopted_by',
#   u'by_maximilien',
#   u'maximilien_de',
#   u'de_robespierre',
#   u'robespierre_to',
#   u'to_attack',
#   u'attack_those',
#   u'those_on',
#   u'on_the',
#   u'the_left',
#   u'left_whom',
#   u'whom_he',
#   u'he_had',
#   u'had_used',
#   u'used_for',
#   u'for_his',
#   u'his_own',
#   u'own_ends',
#   u'ends_during',
#   u'during_the',
#   u'the_french',
#   u'french_revolution',
#   u'revolution_but',
#   u'but_was',
#   u'was_determined',
#   u'determined_to',
#   u'to_get',
#   u'get_rid',
#   u'rid_of',
#   u'of_though',
#   u'though_among',
#   u'among_these',
#   u'these_anarchists',
#   u'anarchists_there',
#   u'there_were',
#   u'were_few',
#   u'few_who',
#   u'who_exhibited',
#   u'exhibited_the',
#   u'the_social',
#   u'social_revolt',
#   u'revolt_characteristics',
#   u'characteristics_of',
#   u'of_later',
#   u'later_anarchists',
#   u'anarchists_there',
#   u'there_would',
#   u'would_be',
#   u'be_many',
#   u'many_revolutionaries',
#   u'revolutionaries_of',
#   u'of_the',
#   u'the_early',
#   u'early_nineteenth',
#   u'nineteenth_century',
#   u'century_who',
#   u'who_contributed',
#   u'contributed_to',
#   u'to_the',
#   u'the_anarchist',
#   u'anarchist_doctrines',
#   u'doctrines_of',
#   u'of_the',
#   u'the_next',
#   u'next_generation',
#   u'generation_such',
#   u'such_as',
#   u'as_william',
#   u'william_godwin',
#   u'godwin_and',
#   u'and_wilhelm',
#   u'wilhelm_weitling',
#   u'weitling_but',
#   u'but_they',
#   u'they_did',
#   u'did_not',
#   u'not_use',
#   u'use_the',
#   u'the_word',
#   u'word_anarchist',
#   u'anarchist_or',
#   u'or_anarchism',
#   u'anarchism_in',
#   u'in_describing',
#   u'describing_themselves',
#   u'themselves_or',
#   u'or_their',
#   u'their_beliefs',
#   u'beliefs_pierrejoseph',
#   u'pierrejoseph_proudhon',
#   u'proudhon_was',
#   u'was_the',
#   u'the_first',
#   u'first_political',
#   u'political_philosopher',
#   u'philosopher_to',
#   u'to_call',
#   u'call_himself',
#   u'himself_an',
#   u'an_anarchist',
#   u'anarchist_making',
#   u'making_the',
#   u'the_formal',
#   u'formal_birth',
#   u'birth_of',
#   u'of_anarchism',
#   u'anarchism_the',
#   u'the_midnineteenth',
#   u'midnineteenth_century',
#   u'century_since',
#   u'since_the',
#   u'the_1890s',
#   u'1890s_from',
#   u'from_france',
#   u'france_the',
#   u'the_term',
#   u'term_libertarianism',
#   u'libertarianism_has',
#   u'has_often',
#   u'often_been',
#   u'been_used',
#   u'used_as',
#   u'as_a',
#   u'a_synonym',
#   u'synonym_for',
#   u'for_anarchism',
#   u'anarchism_and',
#   u'and_was',
#   u'was_used',
#   u'used_almost',
#   u'almost_exclusively',
#   u'exclusively_in',
#   u'in_this',
#   u'this_sense',
#   u'sense_until',
#   u'until_the',
#   u'the_1950s',
#   u'1950s_in',
#   u'in_the',
#   u'the_united',
#   u'united_states',
#   u'states_its',
#   u'its_use',
#   u'use_as',
#   u'as_a',
#   u'a_synonym',
#   u'synonym_is',
#   u'is_still',
#   u'still_common',
#   u'common_outside',
#   u'outside_the',
#   u'the_united',
#   u'united_states',
#   u'states_ward',
#   u'ward_colin',
#   u'colin_anarchism',
#   u'anarchism_a',
#   u'a_very',
#   u'very_short',
#   u'short_introduction',
#   u'introduction_oxford',
#   u'oxford_university',
#   u'university_press',
#   u'press_2004',
#   u'2004_p',
#   u'p_62',
#   u'62_goodway',
#   u'goodway_david',
#   u'david_anarchists',
#   u'anarchists_seed',
#   u'seed_beneath',
#   u'beneath_the',
#   u'the_snow',
#   u'snow_liverpool',
#   u'liverpool_press',
#   u'press_2006',
#   u'2006_p',
#   u'p_4',
#   u'4_macdonald',
#   u'macdonald_dwight',
#   u'dwight_wreszin',
#   u'wreszin_michael',
#   u'michael_interviews',
#   u'interviews_with',
#   u'with_dwight',
#   u'dwight_macdonald',
#   u'macdonald_university',
#   u'university_press',
#   u'press_of',
#   u'of_mississippi',
#   u'mississippi_2003',
#   u'2003_p',
#   u'p_82',
#   u'82_bufe',
#   u'bufe_charles',
#   u'charles_the',
#   u'the_heretics',
#   u'heretics_handbook',
#   u'handbook_of',
#   u'of_quotations',
#   u'quotations_see',
#   u'see_sharp',
#   u'sharp_press',
#   u'press_1992',
#   u'1992_p',
#   u'p_iv',
#   u'iv_gay',
#   u'gay_kathlyn',
#   u'kathlyn_encyclopedia',
#   u'encyclopedia_of',
#   u'of_political',
#   u'political_anarchy',
#   u'anarchy_abcclio',
#   u'abcclio_university',
#   u'university_of',
#   u'of_michigan',
#   u'michigan_2006',
#   u'2006_p',
#   u'p_126',
#   u'126_woodcock',
#   u'woodcock_george',
#   u'george_anarchism',
#   u'anarchism_a',
#   u'a_history',
#   u'history_of',
#   u'of_libertarian',
#   u'libertarian_ideas',
#   u'ideas_and',
#   u'and_movements',
#   u'movements_broadview',
#   u'broadview_press',
#   u'press_2004',
#   u'2004_uses',
#   u'uses_the',
#   u'the_terms',
#   u'terms_interchangeably',
#   u'interchangeably_such',
#   u'such_as',
#   u'as_on',
#   u'on_page',
#   u'page_10',
#   u'10_skirda',
#   u'skirda_alexandre',
#   u'alexandre_facing',
#   u'facing_the',
#   u'the_enemy',
#   u'enemy_a',
#   u'a_history',
#   u'history_of',
#   u'of_anarchist',
#   u'anarchist_organization',
#   u'organization_from',
#   u'from_proudhon',
#   u'proudhon_to',
#   u'to_may',
#   u'may_1968',
#   u'1968_ak',
#   u'ak_press',
#   u'press_2002',
#   u'2002_p',
#   u'p_183',
#   u'183_fernandez',
#   u'fernandez_frank',
#   u'frank_cuban',
#   u'cuban_anarchism',
#   u'anarchism_the',
#   u'the_history',
#   u'history_of',
#   u'of_a',
#   u'a_movement',
#   u'movement_see',
#   u'see_sharp',
#   u'sharp_press',
#   u'press_2001',
#   u'2001_page',
#   u'page_9',
#   u'9_on',
#   u'on_the',
#   u'the_other',
#   u'other_hand',
#   u'hand_some',
#   u'some_use',
#   u'use_libertarianism',
#   u'libertarianism_to',
#   u'to_refer',
#   u'refer_to',
#   u'to_individualistic',
#   u'individualistic_freemarket',
#   u'freemarket_philosophy',
#   u'philosophy_only',
#   u'only_referring',
#   u'referring_to',
#   u'to_freemarket',
#   u'freemarket_anarchism',
#   u'anarchism_as',
#   u'as_libertarian',
#   u'libertarian_anarchism',
#   u'anarchism_history',
#   u'history_origins',
#   u'origins_the',
#   u'the_earliest',
#   u'earliest_taoism',
#   u'taoism_in',
#   u'in_ancient',
#   u'ancient_china',
#   u'china_anarchist',
#   u'anarchist_themes',
#   u'themes_can',
#   u'can_be',
#   u'be_found',
#   u'found_in',
#   u'in_the',
#   u'the_6th',
#   u'6th_century',
#   u'century_bc',
#   u'bc_among',
#   u'among_the',
#   u'the_works',
#   u'works_of',
#   u'of_taoist',
#   u'taoist_philosopher',
#   u'philosopher_laozi',
#   u'laozi_peter',
#   u'peter_kropotkin',
#   u'kropotkin_anarchism',
#   u'anarchism_encyclopdia',
#   u'encyclopdia_britannica',
#   u'britannica_1910',
#   u'1910_and',
#   u'and_in',
#   u'in_later',
#   u'later_centuries',
#   u'centuries_by',
#   u'by_zhuangzi',
#   u'zhuangzi_and',
#   u'and_bao',
#   u'bao_jingyan',
#   u'jingyan_anarchism',
#   u'anarchism_a',
#   u'a_documentary',
#   u'documentary_history',
#   u'history_of',
#   u'of_libertarian',
#   u'libertarian_ideas',
#   u'ideas_volume',
#   u'volume_one',
#   u'one_from',
#   u'from_anarchy',
#   u'anarchy_to',
#   u'to_anarchism',
#   u'anarchism_300ce1939',
#   u'300ce1939_robert',
#   u'robert_grahams',
#   u'grahams_anarchism',
#   u'anarchism_weblog',
#   u'weblog_zhuangzis',
#   u'zhuangzis_philosophy',
#   u'philosophy_has',
#   u'has_been',
#   u'been_described',
#   u'described_by',
#   u'by_various',
#   u'various_sources',
#   u'sources_as',
#   u'as_anarchist',
#   u'anarchist_zhuangzi',
#   u'zhuangzi_wrote',
#   u'wrote_a',
#   u'a_petty',
#   u'petty_thief',
#   u'thief_is',
#   u'is_put',
#   u'put_in',
#   u'in_jail',
#   u'jail_a',
#   u'a_great',
#   u'great_becomes',
#   u'becomes_a',
#   u'a_ruler',
#   u'ruler_of',
#   u'of_a',
#   u'a_nation',
#   u'nation_diogenes',
#   u'diogenes_of',
#   u'of_sinope',
#   u'sinope_and',
#   u'and_the',
#   u'the_cynics',
#   u'cynics_their',
#   u'their_contemporary',
#   u'contemporary_zeno',
#   u'zeno_of',
#   u'of_citium',
#   u'citium_the',
#   u'the_founder',
#   u'founder_of',
#   u'of_stoicism',
#   u'stoicism_also',
#   u'also_introduced',
#   u'introduced_similar',
#   u'similar_topics',
#   u'topics_jesus',
#   u'jesus_is',
#   u'is_sometimes',
#   u'sometimes_considered',
#   u'considered_the',
#   u'the_first',
#   u'first_anarchist',
#   u'anarchist_in',
#   u'in_the',
#   u'the_christian',
#   u'christian_anarchist',
#   u'anarchist_tradition',
#   u'tradition_georges',
#   u'georges_lechartier',
#   u'lechartier_wrote',
#   u'wrote_that',
#   u'that_the',
#   u'the_true',
#   u'true_founder',
#   u'founder_of',
#   u'of_anarchy',
#   u'anarchy_was',
#   u'was_jesus',
#   u'jesus_christ',
#   u'christ_and',
#   u'and_the',
#   u'the_first',
#   u'first_anarchist',
#   u'anarchist_society',
#   u'society_was',
#   u'was_that',
#   u'that_of',
#   u'of_the',
#   u'the_apostles',
#   u'apostles_such',
#   u'such_a',
#   u'a_distinction',
#   u'distinction_reverberates',
#   u'reverberates_subversive',
#   u'subversive_religious',
#   u'religious_conceptions',
#   u'conceptions_like',
#   u'like_the',
#   u'the_aforementioned',
#   u'aforementioned_seemingly',
#   u'seemingly_anarchistic',
#   u'anarchistic_taoist',
#   u'taoist_teachings',
#   u'teachings_and',
#   u'and_that',
#   u'that_of',
#   u'of_other',
#   u'other_antiauthoritarian',
#   u'antiauthoritarian_religious',
#   u'religious_traditions',
#   u'traditions_creating',
#   u'creating_a',
#   u'a_complex',
#   u'complex_relationship',
#   u'relationship_regarding',
#   u'regarding_the',
#   u'the_question',
#   u'question_as',
#   u'as_to',
#   u'to_whether',
#   u'whether_or',
#   u'or_not',
#   u'not_anarchism',
#   u'anarchism_and',
#   u'and_religion',
#   u'religion_are',
#   u'are_compatible',
#   u'compatible_this',
#   u'this_is',
#   u'is_exemplified',
#   u'exemplified_when',
#   u'when_the',
#   u'the_glorification',
#   u'glorification_of',
#   u'of_the',
#   u'the_state',
#   u'state_is',
#   u'is_viewed',
#   u'viewed_as',
#   u'as_a',
#   u'a_form',
#   u'form_of',
#   u'of_sinful',
#   u'sinful_idolatry',
#   u'idolatry_the',
#   u'the_french',
#   u'french_renaissance',
#   u'renaissance_political',
#   u'political_philosopher',
#   u'philosopher_tienne',
#   u'tienne_de',
#   u'de_la',
#   u'la_botie',
#   u'botie_has',
#   u'has_been',
#   u'been_said',
#   u'said_to',
#   u'to_write',
#   u'write_an',
#   u'an_important',
#   u'important_anarchist',
#   u'anarchist_precedent',
#   u'precedent_in',
#   u'in_his',
#   u'his_most',
#   u'most_famous',
#   u'famous_work',
#   u'work_the',
#   u'the_discourse',
#   u'discourse_on',
#   u'on_voluntary',
#   u'voluntary_servitude',
#   u'servitude_the',
#   u'the_radical',
#   u'radical_protestant',
#   u'protestant_christian',
#   u'christian_gerrard',
#   u'gerrard_winstanley',
#   u'winstanley_and',
#   u'and_his',
#   u'his_group',
#   u'group_the',
#   u'the_diggers',
#   u'diggers_are',
#   u'are_cited',
#   u'cited_by',
#   u'by_various',
#   u'various_authors',
#   u'authors_as',
#   u'as_proposing',
#   u'proposing_anarchist',
#   u'anarchist_social',
#   u'social_measures',
#   u'measures_in',
#   u'in_the',
#   u'the_17th',
#   u'17th_century',
#   u'century_in',
#   u'in_england',
#   u'england_the',
#   u'the_term',
#   u'term_anarchist',
#   u'anarchist_first',
#   u'first_entered',
#   u'entered_the',
#   u'the_english',
#   u'english_language',
#   u'language_in',
#   u'in_1642',
#   u'1642_during',
#   u'during_the',
#   u'the_english',
#   u'english_civil',
#   u'civil_war',
#   u'war_as',
#   u'as_a',
#   u'a_term',
#   u'term_of',
#   u'of_abuse',
#   u'abuse_used',
#   u'used_by',
#   u'by_royalists',
#   u'royalists_against',
#   u'against_their',
#   u'their_roundhead',
#   u'roundhead_opponents',
#   u'opponents_by',
#   u'by_the',
#   u'the_time',
#   u'time_of',
#   u'of_the',
#   u'the_french',
#   u'french_revolution',
#   u'revolution_some',
#   u'some_such',
#   u'such_as',
#   u'as_the',
#   u'the_enrags',
#   u'enrags_began',
#   u'began_to',
#   u'to_use',
#   u'use_the',
#   u'the_term',
#   u'term_positively',
#   u'positively_in',
#   u'in_opposition',
#   u'opposition_to',
#   u'to_jacobin',
#   u'jacobin_centralisation',
#   u'centralisation_of',
#   u'of_power',
#   u'power_seeing',
#   u'seeing_revolutionary',
#   u'revolutionary_government',
#   u'government_as',
#   u'as_oxymoronic',
#   u'oxymoronic_by',
#   u'by_the',
#   u'the_turn',
#   u'turn_of',
#   u'of_the',
#   u'the_19th',
#   u'19th_century',
#   u'century_the',
#   u'the_english',
#   u'english_word',
#   u'word_anarchism',
#   u'anarchism_had',
#   u'had_lost',
#   u'lost_its',
#   u'its_initial',
#   u'initial_negative',
#   u'negative_connotation',
#   u'connotation_modern',
#   u'modern_anarchism',
#   u'anarchism_sprang',
#   u'sprang_from',
#   u'from_the',
#   u'the_secular',
#   u'secular_or',
#   u'or_religious',
#   u'religious_thought',
#   u'thought_of',
#   u'of_the',
#   u'the_enlightenment',
#   u'enlightenment_particularly',
#   ...],
#  [u'autism_autism',
#   u'autism_is',
#   u'is_a',
#   u'a_disorder',
#   u'disorder_of',
#   u'of_neural',
#   u'neural_development',
#   u'development_characterized',
#   u'characterized_by',
#   u'by_impaired',
#   u'impaired_social',
#   u'social_interaction',
#   u'interaction_and',
#   u'and_communication',
#   u'communication_and',
#   u'and_by',
#   u'by_restricted',
#   u'restricted_and',
#   u'and_repetitive',
#   u'repetitive_behavior',
#   u'behavior_the',
#   u'the_diagnostic',
#   u'diagnostic_criteria',
#   u'criteria_require',
#   u'require_that',
#   u'that_symptoms',
#   u'symptoms_become',
#   u'become_apparent',
#   u'apparent_before',
#   u'before_a',
#   u'a_child',
#   u'child_is',
#   u'is_three',
#   u'three_years',
#   u'years_old',
#   u'old_autism',
#   u'autism_affects',
#   u'affects_information',
#   u'information_processing',
#   u'processing_in',
#   u'in_the',
#   u'the_brain',
#   u'brain_by',
#   u'by_altering',
#   u'altering_how',
#   u'how_nerve',
#   u'nerve_cells',
#   u'cells_and',
#   u'and_their',
#   u'their_synapses',
#   u'synapses_connect',
#   u'connect_and',
#   u'and_organize',
#   u'organize_how',
#   u'how_this',
#   u'this_occurs',
#   u'occurs_is',
#   u'is_not',
#   u'not_well',
#   u'well_understood',
#   u'understood_it',
#   u'it_is',
#   u'is_one',
#   u'one_of',
#   u'of_three',
#   u'three_recognized',
#   u'recognized_disorders',
#   u'disorders_in',
#   u'in_the',
#   u'the_autism',
#   u'autism_spectrum',
#   u'spectrum_asds',
#   u'asds_the',
#   u'the_other',
#   u'other_two',
#   u'two_being',
#   u'being_asperger',
#   u'asperger_syndrome',
#   u'syndrome_which',
#   u'which_lacks',
#   u'lacks_delays',
#   u'delays_in',
#   u'in_cognitive',
#   u'cognitive_development',
#   u'development_and',
#   u'and_language',
#   u'language_and',
#   u'and_pervasive',
#   u'pervasive_developmental',
#   u'developmental_disorder',
#   u'disorder_not',
#   u'not_otherwise',
#   u'otherwise_specified',
#   u'specified_commonly',
#   u'commonly_abbreviated',
#   u'abbreviated_as',
#   u'as_pddnos',
#   u'pddnos_which',
#   u'which_is',
#   u'is_diagnosed',
#   u'diagnosed_when',
#   u'when_the',
#   u'the_full',
#   u'full_set',
#   u'set_of',
#   u'of_criteria',
#   u'criteria_for',
#   u'for_autism',
#   u'autism_or',
#   u'or_asperger',
#   u'asperger_syndrome',
#   u'syndrome_are',
#   u'are_not',
#   u'not_met',
#   u'met_autism',
#   u'autism_has',
#   u'has_a',
#   u'a_strong',
#   u'strong_genetic',
#   u'genetic_basis',
#   u'basis_although',
#   u'although_the',
#   u'the_genetics',
#   u'genetics_of',
#   u'of_autism',
#   u'autism_are',
#   u'are_complex',
#   u'complex_and',
#   u'and_it',
#   u'it_is',
#   u'is_unclear',
#   u'unclear_whether',
#   u'whether_asd',
#   u'asd_is',
#   u'is_explained',
#   u'explained_more',
#   u'more_by',
#   u'by_rare',
#   u'rare_mutations',
#   u'mutations_or',
#   u'or_by',
#   u'by_rare',
#   u'rare_combinations',
#   u'combinations_of',
#   u'of_common',
#   u'common_genetic',
#   u'genetic_variants',
#   u'variants_in',
#   u'in_rare',
#   u'rare_cases',
#   u'cases_autism',
#   u'autism_is',
#   u'is_strongly',
#   u'strongly_associated',
#   u'associated_with',
#   u'with_agents',
#   u'agents_that',
#   u'that_cause',
#   u'cause_birth',
#   u'birth_defects',
#   u'defects_controversies',
#   u'controversies_surround',
#   u'surround_other',
#   u'other_proposed',
#   u'proposed_environmental',
#   u'environmental_causes',
#   u'causes_such',
#   u'such_as',
#   u'as_heavy',
#   u'heavy_metals',
#   u'metals_pesticides',
#   u'pesticides_or',
#   u'or_childhood',
#   u'childhood_vaccines',
#   u'vaccines_the',
#   u'the_vaccine',
#   u'vaccine_hypotheses',
#   u'hypotheses_are',
#   u'are_biologically',
#   u'biologically_implausible',
#   u'implausible_and',
#   u'and_lack',
#   u'lack_convincing',
#   u'convincing_scientific',
#   u'scientific_evidence',
#   u'evidence_the',
#   u'the_prevalence',
#   u'prevalence_of',
#   u'of_autism',
#   u'autism_is',
#   u'is_about',
#   u'about_12',
#   u'12_per',
#   u'per_1000',
#   u'1000_people',
#   u'people_worldwide',
#   u'worldwide_and',
#   u'and_the',
#   u'the_centers',
#   u'centers_for',
#   u'for_disease',
#   u'disease_control',
#   u'control_and',
#   u'and_prevention',
#   u'prevention_cdc',
#   u'cdc_report',
#   u'report_20',
#   u'20_per',
#   u'per_1000',
#   u'1000_children',
#   u'children_in',
#   u'in_the',
#   u'the_united',
#   u'united_states',
#   u'states_are',
#   u'are_diagnosed',
#   u'diagnosed_with',
#   u'with_asd',
#   u'asd_up',
#   u'up_from',
#   u'from_11',
#   u'11_per',
#   u'per_1000',
#   u'1000_in',
#   u'in_2008',
#   u'2008_the',
#   u'the_number',
#   u'number_of',
#   u'of_people',
#   u'people_diagnosed',
#   u'diagnosed_with',
#   u'with_autism',
#   u'autism_has',
#   u'has_been',
#   u'been_increasing',
#   u'increasing_dramatically',
#   u'dramatically_since',
#   u'since_the',
#   u'the_1980s',
#   u'1980s_partly',
#   u'partly_due',
#   u'due_to',
#   u'to_changes',
#   u'changes_in',
#   u'in_diagnostic',
#   u'diagnostic_practice',
#   u'practice_and',
#   u'and_governmentsubsidized',
#   u'governmentsubsidized_financial',
#   u'financial_incentives',
#   u'incentives_for',
#   u'for_named',
#   u'named_diagnoses',
#   u'diagnoses_the',
#   u'the_question',
#   u'question_of',
#   u'of_whether',
#   u'whether_actual',
#   u'actual_prevalence',
#   u'prevalence_has',
#   u'has_increased',
#   u'increased_is',
#   u'is_unresolved',
#   u'unresolved_parents',
#   u'parents_usually',
#   u'usually_notice',
#   u'notice_signs',
#   u'signs_in',
#   u'in_the',
#   u'the_first',
#   u'first_two',
#   u'two_years',
#   u'years_of',
#   u'of_their',
#   u'their_childs',
#   u'childs_life',
#   u'life_the',
#   u'the_signs',
#   u'signs_usually',
#   u'usually_develop',
#   u'develop_gradually',
#   u'gradually_but',
#   u'but_some',
#   u'some_autistic',
#   u'autistic_children',
#   u'children_first',
#   u'first_develop',
#   u'develop_more',
#   u'more_normally',
#   u'normally_and',
#   u'and_then',
#   u'then_regress',
#   u'regress_early',
#   u'early_behavioral',
#   u'behavioral_or',
#   u'or_cognitive',
#   u'cognitive_intervention',
#   u'intervention_can',
#   u'can_help',
#   u'help_autistic',
#   u'autistic_children',
#   u'children_gain',
#   u'gain_selfcare',
#   u'selfcare_social',
#   u'social_and',
#   u'and_communication',
#   u'communication_skills',
#   u'skills_although',
#   u'although_there',
#   u'there_is',
#   u'is_no',
#   u'no_known',
#   u'known_cure',
#   u'cure_there',
#   u'there_have',
#   u'have_been',
#   u'been_reported',
#   u'reported_cases',
#   u'cases_of',
#   u'of_children',
#   u'children_who',
#   u'who_recovered',
#   u'recovered_not',
#   u'not_many',
#   u'many_children',
#   u'children_with',
#   u'with_autism',
#   u'autism_live',
#   u'live_independently',
#   u'independently_after',
#   u'after_reaching',
#   u'reaching_adulthood',
#   u'adulthood_though',
#   u'though_some',
#   u'some_become',
#   u'become_successful',
#   u'successful_an',
#   u'an_autistic',
#   u'autistic_culture',
#   u'culture_has',
#   u'has_developed',
#   u'developed_with',
#   u'with_some',
#   u'some_individuals',
#   u'individuals_seeking',
#   u'seeking_a',
#   u'a_cure',
#   u'cure_and',
#   u'and_others',
#   u'others_believing',
#   u'believing_autism',
#   u'autism_should',
#   u'should_be',
#   u'be_accepted',
#   u'accepted_as',
#   u'as_a',
#   u'a_difference',
#   u'difference_and',
#   u'and_not',
#   u'not_treated',
#   u'treated_as',
#   u'as_a',
#   u'a_disorder',
#   u'disorder_characteristicsautism',
#   u'characteristicsautism_is',
#   u'is_a',
#   u'a_highly',
#   u'highly_variable',
#   u'variable_neurodevelopmental',
#   u'neurodevelopmental_disorder',
#   u'disorder_that',
#   u'that_first',
#   u'first_appears',
#   u'appears_during',
#   u'during_infancy',
#   u'infancy_or',
#   u'or_childhood',
#   u'childhood_and',
#   u'and_generally',
#   u'generally_follows',
#   u'follows_a',
#   u'a_steady',
#   u'steady_course',
#   u'course_without',
#   u'without_remission',
#   u'remission_overt',
#   u'overt_symptoms',
#   u'symptoms_gradually',
#   u'gradually_begin',
#   u'begin_after',
#   u'after_the',
#   u'the_age',
#   u'age_of',
#   u'of_six',
#   u'six_months',
#   u'months_become',
#   u'become_established',
#   u'established_by',
#   u'by_age',
#   u'age_two',
#   u'two_or',
#   u'or_three',
#   u'three_years',
#   u'years_and',
#   u'and_tend',
#   u'tend_to',
#   u'to_continue',
#   u'continue_through',
#   u'through_adulthood',
#   u'adulthood_although',
#   u'although_often',
#   u'often_in',
#   u'in_more',
#   u'more_muted',
#   u'muted_form',
#   u'form_it',
#   u'it_is',
#   u'is_distinguished',
#   u'distinguished_not',
#   u'not_by',
#   u'by_a',
#   u'a_single',
#   u'single_symptom',
#   u'symptom_but',
#   u'but_by',
#   u'by_a',
#   u'a_characteristic',
#   u'characteristic_triad',
#   u'triad_of',
#   u'of_symptoms',
#   u'symptoms_impairments',
#   u'impairments_in',
#   u'in_social',
#   u'social_interaction',
#   u'interaction_impairments',
#   u'impairments_in',
#   u'in_communication',
#   u'communication_and',
#   u'and_restricted',
#   u'restricted_interests',
#   u'interests_and',
#   u'and_repetitive',
#   u'repetitive_behavior',
#   u'behavior_other',
#   u'other_aspects',
#   u'aspects_such',
#   u'such_as',
#   u'as_atypical',
#   u'atypical_eating',
#   u'eating_are',
#   u'are_also',
#   u'also_common',
#   u'common_but',
#   u'but_are',
#   u'are_not',
#   u'not_essential',
#   u'essential_for',
#   u'for_diagnosis',
#   u'diagnosis_autisms',
#   u'autisms_individual',
#   u'individual_symptoms',
#   u'symptoms_occur',
#   u'occur_in',
#   u'in_the',
#   u'the_general',
#   u'general_population',
#   u'population_and',
#   u'and_appear',
#   u'appear_not',
#   u'not_to',
#   u'to_associate',
#   u'associate_highly',
#   u'highly_without',
#   u'without_a',
#   u'a_sharp',
#   u'sharp_line',
#   u'line_separating',
#   u'separating_pathologically',
#   u'pathologically_severe',
#   u'severe_from',
#   u'from_common',
#   u'common_traits',
#   u'traits_social',
#   u'social_developmentsocial',
#   u'developmentsocial_deficits',
#   u'deficits_distinguish',
#   u'distinguish_autism',
#   u'autism_and',
#   u'and_the',
#   u'the_related',
#   u'related_autism',
#   u'autism_spectrum',
#   u'spectrum_disorders',
#   u'disorders_asd',
#   u'asd_see',
#   u'see_classification',
#   u'classification_from',
#   u'from_other',
#   u'other_developmental',
#   u'developmental_disorders',
#   u'disorders_people',
#   u'people_with',
#   u'with_autism',
#   u'autism_have',
#   u'have_social',
#   u'social_impairments',
#   u'impairments_and',
#   u'and_often',
#   u'often_lack',
#   u'lack_the',
#   u'the_intuition',
#   u'intuition_about',
#   u'about_others',
#   u'others_that',
#   u'that_many',
#   u'many_people',
#   u'people_take',
#   u'take_for',
#   u'for_granted',
#   u'granted_noted',
#   u'noted_autistic',
#   u'autistic_temple',
#   u'temple_grandin',
#   u'grandin_described',
#   u'described_her',
#   u'her_inability',
#   u'inability_to',
#   u'to_understand',
#   u'understand_the',
#   u'the_social',
#   u'social_communication',
#   u'communication_of',
#   u'of_neurotypicals',
#   u'neurotypicals_or',
#   u'or_people',
#   u'people_with',
#   u'with_normal',
#   u'normal_neural',
#   u'neural_development',
#   u'development_as',
#   u'as_leaving',
#   u'leaving_her',
#   u'her_feeling',
#   u'feeling_like',
#   u'like_an',
#   u'an_anthropologist',
#   u'anthropologist_on',
#   u'on_mars',
#   u'mars_unusual',
#   u'unusual_social',
#   u'social_development',
#   u'development_becomes',
#   u'becomes_apparent',
#   u'apparent_early',
#   u'early_in',
#   u'in_childhood',
#   u'childhood_autistic',
#   u'autistic_infants',
#   u'infants_show',
#   u'show_less',
#   u'less_attention',
#   u'attention_to',
#   u'to_social',
#   u'social_stimuli',
#   u'stimuli_smile',
#   u'smile_and',
#   u'and_look',
#   u'look_at',
#   u'at_others',
#   u'others_less',
#   u'less_often',
#   u'often_and',
#   u'and_respond',
#   u'respond_less',
#   u'less_to',
#   u'to_their',
#   u'their_own',
#   u'own_name',
#   u'name_autistic',
#   u'autistic_toddlers',
#   u'toddlers_differ',
#   u'differ_more',
#   u'more_strikingly',
#   u'strikingly_from',
#   u'from_social',
#   u'social_norms',
#   u'norms_for',
#   u'for_example',
#   u'example_they',
#   u'they_have',
#   u'have_less',
#   u'less_eye',
#   u'eye_contact',
#   u'contact_and',
#   u'and_turn',
#   u'turn_taking',
#   u'taking_and',
#   u'and_do',
#   u'do_not',
#   u'not_have',
#   u'have_the',
#   u'the_ability',
#   u'ability_to',
#   u'to_use',
#   u'use_simple',
#   u'simple_movements',
#   u'movements_to',
#   u'to_express',
#   u'express_themselves',
#   u'themselves_such',
#   u'such_as',
#   u'as_the',
#   u'the_deficiency',
#   u'deficiency_to',
#   u'to_point',
#   u'point_at',
#   u'at_things',
#   u'things_three',
#   u'three_to',
#   u'to_fiveyearold',
#   u'fiveyearold_autistic',
#   u'autistic_children',
#   u'children_are',
#   u'are_less',
#   u'less_likely',
#   u'likely_to',
#   u'to_exhibit',
#   u'exhibit_social',
#   u'social_understanding',
#   u'understanding_approach',
#   u'approach_others',
#   u'others_spontaneously',
#   u'spontaneously_imitate',
#   u'imitate_and',
#   u'and_respond',
#   u'respond_to',
#   u'to_emotions',
#   u'emotions_communicate',
#   u'communicate_nonverbally',
#   u'nonverbally_and',
#   u'and_take',
#   u'take_turns',
#   u'turns_with',
#   u'with_others',
#   u'others_however',
#   u'however_they',
#   u'they_do',
#   u'do_form',
#   u'form_attachments',
#   u'attachments_to',
#   u'to_their',
#   u'their_primary',
#   u'primary_caregivers',
#   u'caregivers_most',
#   u'most_autistic',
#   u'autistic_children',
#   u'children_display',
#   u'display_moderately',
#   u'moderately_less',
#   u'less_attachment',
#   u'attachment_security',
#   u'security_than',
#   u'than_nonautistic',
#   u'nonautistic_children',
#   u'children_although',
#   u'although_this',
#   u'this_difference',
#   u'difference_disappears',
#   u'disappears_in',
#   u'in_children',
#   u'children_with',
#   u'with_higher',
#   u'higher_mental',
#   u'mental_development',
#   u'development_or',
#   u'or_less',
#   u'less_severe',
#   u'severe_asd',
#   u'asd_older',
#   u'older_children',
#   u'children_and',
#   u'and_adults',
#   u'adults_with',
#   u'with_asd',
#   u'asd_perform',
#   u'perform_worse',
#   u'worse_on',
#   u'on_tests',
#   u'tests_of',
#   u'of_face',
#   u'face_and',
#   u'and_emotion',
#   u'emotion_recognition',
#   u'recognition_for',
#   u'for_further',
#   u'further_information',
#   u'information_on',
#   u'on_facial',
#   u'facial_recognition',
#   u'recognition_and',
#   u'and_processing',
#   u'processing_in',
#   u'in_individuals',
#   u'individuals_with',
#   u'with_asd',
#   u'asd_see',
#   u'see_the',
#   u'the_autism',
#   u'autism_and',
#   u'and_facial',
#   u'facial_recognition',
#   u'recognition_section',
#   u'section_of',
#   u'of_face',
#   u'face_perceptionchildren',
#   u'perceptionchildren_with',
#   u'with_highfunctioning',
#   u'highfunctioning_autism',
#   u'autism_suffer',
#   u'suffer_from',
#   u'from_more',
#   u'more_intense',
#   u'intense_and',
#   u'and_frequent',
#   u'frequent_loneliness',
#   u'loneliness_compared',
#   u'compared_to',
#   u'to_nonautistic',
#   u'nonautistic_peers',
#   u'peers_despite',
#   u'despite_the',
#   u'the_common',
#   u'common_belief',
#   u'belief_that',
#   u'that_children',
#   u'children_with',
#   u'with_autism',
#   u'autism_prefer',
#   u'prefer_to',
#   u'to_be',
#   u'be_alone',
#   u'alone_making',
#   u'making_and',
#   u'and_maintaining',
#   u'maintaining_friendships',
#   u'friendships_often',
#   u'often_proves',
#   u'proves_to',
#   u'to_be',
#   u'be_difficult',
#   u'difficult_for',
#   u'for_those',
#   u'those_with',
#   u'with_autism',
#   u'autism_for',
#   u'for_them',
#   u'them_the',
#   u'the_quality',
#   u'quality_of',
#   u'of_friendships',
#   u'friendships_not',
#   u'not_the',
#   u'the_number',
#   u'number_of',
#   u'of_friends',
#   u'friends_predicts',
#   u'predicts_how',
#   u'how_lonely',
#   u'lonely_they',
#   u'they_feel',
#   u'feel_functional',
#   u'functional_friendships',
#   u'friendships_such',
#   u'such_as',
#   u'as_those',
#   u'those_resulting',
#   u'resulting_in',
#   u'in_invitations',
#   u'invitations_to',
#   u'to_parties',
#   u'parties_may',
#   u'may_affect',
#   u'affect_the',
#   u'the_quality',
#   u'quality_of',
#   u'of_life',
#   u'life_more',
#   u'more_deeply',
#   u'deeply_there',
#   u'there_are',
#   u'are_many',
#   u'many_anecdotal',
#   u'anecdotal_reports',
#   u'reports_but',
#   u'but_few',
#   u'few_systematic',
#   u'systematic_studies',
#   u'studies_of',
#   u'of_aggression',
#   u'aggression_and',
#   u'and_violence',
#   u'violence_in',
#   u'in_individuals',
#   u'individuals_with',
#   u'with_asd',
#   u'asd_the',
#   u'the_limited',
#   u'limited_data',
#   u'data_suggest',
#   u'suggest_that',
#   u'that_in',
#   u'in_children',
#   u'children_with',
#   u'with_mental',
#   u'mental_retardation',
#   u'retardation_autism',
#   u'autism_is',
#   u'is_associated',
#   u'associated_with',
#   u'with_aggression',
#   u'aggression_destruction',
#   u'destruction_of',
#   u'of_property',
#   u'property_and',
#   u'and_tantrums',
#   u'tantrums_a',
#   u'a_2007',
#   u'2007_study',
#   u'study_interviewed',
#   u'interviewed_parents',
#   u'parents_of',
#   u'of_67',
#   u'67_children',
#   u'children_with',
#   u'with_asd',
#   u'asd_and',
#   u'and_reported',
#   u'reported_that',
#   u'that_about',
#   u'about_twothirds',
#   u'twothirds_of',
#   u'of_the',
#   u'the_children',
#   u'children_had',
#   u'had_periods',
#   u'periods_of',
#   u'of_severe',
#   u'severe_tantrums',
#   u'tantrums_and',
#   u'and_about',
#   u'about_onethird',
#   u'onethird_had',
#   u'had_a',
#   u'a_history',
#   u'history_of',
#   u'of_aggression',
#   u'aggression_with',
#   u'with_tantrums',
#   u'tantrums_significantly',
#   u'significantly_more',
#   u'more_common',
#   u'common_than',
#   u'than_in',
#   u'in_nonautistic',
#   u'nonautistic_children',
#   u'children_with',
#   u'with_language',
#   u'language_impairments',
#   u'impairments_a',
#   u'a_2008',
#   u'2008_swedish',
#   u'swedish_study',
#   u'study_found',
#   u'found_that',
#   u'that_of',
#   u'of_individuals',
#   u'individuals_aged',
#   u'aged_15',
#   u'15_or',
#   u'or_older',
#   u'older_discharged',
#   u'discharged_from',
#   u'from_hospital',
#   u'hospital_with',
#   u'with_a',
#   u'a_diagnosis',
#   u'diagnosis_of',
#   u'of_asd',
#   u'asd_those',
#   u'those_who',
#   u'who_committed',
#   u'committed_violent',
#   u'violent_crimes',
#   u'crimes_were',
#   u'were_significantly',
#   u'significantly_more',
#   u'more_likely',
#   u'likely_to',
#   u'to_have',
#   u'have_other',
#   u'other_psychopathological',
#   u'psychopathological_conditions',
#   u'conditions_such',
#   u'such_as',
#   u'as_psychosis',
#   u'psychosis_communicationabout',
#   u'communicationabout_a',
#   u'a_third',
#   u'third_to',
#   u'to_a',
#   u'a_half',
#   u'half_of',
#   u'of_individuals',
#   u'individuals_with',
#   u'with_autism',
#   u'autism_do',
#   u'do_not',
#   u'not_develop',
#   u'develop_enough',
#   u'enough_natural',
#   u'natural_speech',
#   u'speech_to',
#   u'to_meet',
#   u'meet_their',
#   u'their_daily',
#   u'daily_communication',
#   u'communication_needs',
#   u'needs_differences',
#   u'differences_in',
#   u'in_communication',
#   u'communication_may',
#   u'may_be',
#   u'be_present',
#   u'present_from',
#   u'from_the',
#   u'the_first',
#   u'first_year',
#   u'year_of',
#   u'of_life',
#   u'life_and',
#   u'and_may',
#   u'may_include',
#   u'include_delayed',
#   u'delayed_onset',
#   u'onset_of',
#   u'of_babbling',
#   u'babbling_unusual',
#   u'unusual_gestures',
#   u'gestures_diminished',
#   u'diminished_responsiveness',
#   u'responsiveness_and',
#   u'and_vocal',
#   u'vocal_patterns',
#   u'patterns_that',
#   u'that_are',
#   u'are_not',
#   u'not_synchronized',
#   u'synchronized_with',
#   u'with_the',
#   u'the_caregiver',
#   u'caregiver_in',
#   u'in_the',
#   u'the_second',
#   u'second_and',
#   u'and_third',
#   u'third_years',
#   u'years_autistic',
#   u'autistic_children',
#   u'children_have',
#   u'have_less',
#   u'less_frequent',
#   u'frequent_and',
#   u'and_less',
#   u'less_diverse',
#   u'diverse_babbling',
#   u'babbling_consonants',
#   u'consonants_words',
#   u'words_and',
#   u'and_word',
#   u'word_combinations',
#   u'combinations_their',
#   u'their_gestures',
#   u'gestures_are',
#   u'are_less',
#   u'less_often',
#   u'often_integrated',
#   u'integrated_with',
#   u'with_words',
#   u'words_autistic',
#   u'autistic_children',
#   u'children_are',
#   u'are_less',
#   u'less_likely',
#   u'likely_to',
#   u'to_make',
#   u'make_requests',
#   u'requests_or',
#   u'or_share',
#   u'share_experiences',
#   u'experiences_and',
#   ...],
#  [u'albedo_albedo',
#   u'albedo_or',
#   u'or_reflection',
#   u'reflection_coefficient',
#   u'coefficient_derived',
#   u'derived_from',
#   u'from_latin',
#   u'latin_albedo',
#   u'albedo_whiteness',
#   u'whiteness_or',
#   u'or_reflected',
#   u'reflected_sunlight',
#   u'sunlight_in',
#   u'in_turn',
#   u'turn_from',
#   u'from_albus',
#   u'albus_white',
#   u'white_is',
#   u'is_the',
#   u'the_diffuse',
#   u'diffuse_reflectivity',
#   u'reflectivity_or',
#   u'or_reflecting',
#   u'reflecting_power',
#   u'power_of',
#   u'of_a',
#   u'a_surface',
#   u'surface_it',
#   u'it_is',
#   u'is_defined',
#   u'defined_as',
#   u'as_the',
#   u'the_ratio',
#   u'ratio_of',
#   u'of_reflected',
#   u'reflected_radiation',
#   u'radiation_from',
#   u'from_the',
#   u'the_surface',
#   u'surface_to',
#   u'to_incident',
#   u'incident_radiation',
#   u'radiation_upon',
#   u'upon_it',
#   u'it_being',
#   u'being_a',
#   u'a_dimensionless',
#   u'dimensionless_fraction',
#   u'fraction_it',
#   u'it_may',
#   u'may_also',
#   u'also_be',
#   u'be_expressed',
#   u'expressed_as',
#   u'as_a',
#   u'a_percentage',
#   u'percentage_and',
#   u'and_is',
#   u'is_measured',
#   u'measured_on',
#   u'on_a',
#   u'a_scale',
#   u'scale_from',
#   u'from_zero',
#   u'zero_for',
#   u'for_no',
#   u'no_reflecting',
#   u'reflecting_power',
#   u'power_of',
#   u'of_a',
#   u'a_perfectly',
#   u'perfectly_black',
#   u'black_surface',
#   u'surface_to',
#   u'to_1',
#   u'1_for',
#   u'for_perfect',
#   u'perfect_reflection',
#   u'reflection_of',
#   u'of_a',
#   u'a_white',
#   u'white_surfacealbedo',
#   u'surfacealbedo_depends',
#   u'depends_on',
#   u'on_the',
#   u'the_frequency',
#   u'frequency_of',
#   u'of_the',
#   u'the_radiation',
#   u'radiation_when',
#   u'when_quoted',
#   u'quoted_unqualified',
#   u'unqualified_it',
#   u'it_usually',
#   u'usually_refers',
#   u'refers_to',
#   u'to_some',
#   u'some_appropriate',
#   u'appropriate_average',
#   u'average_across',
#   u'across_the',
#   u'the_spectrum',
#   u'spectrum_of',
#   u'of_visible',
#   u'visible_light',
#   u'light_in',
#   u'in_general',
#   u'general_the',
#   u'the_albedo',
#   u'albedo_depends',
#   u'depends_on',
#   u'on_the',
#   u'the_directional',
#   u'directional_distribution',
#   u'distribution_of',
#   u'of_incoming',
#   u'incoming_radiation',
#   u'radiation_exceptions',
#   u'exceptions_are',
#   u'are_lambertian',
#   u'lambertian_surfaces',
#   u'surfaces_which',
#   u'which_scatter',
#   u'scatter_radiation',
#   u'radiation_in',
#   u'in_all',
#   u'all_directions',
#   u'directions_according',
#   u'according_to',
#   u'to_a',
#   u'a_cosine',
#   u'cosine_function',
#   u'function_so',
#   u'so_their',
#   u'their_albedo',
#   u'albedo_does',
#   u'does_not',
#   u'not_depend',
#   u'depend_on',
#   u'on_the',
#   u'the_incident',
#   u'incident_distribution',
#   u'distribution_in',
#   u'in_practice',
#   u'practice_a',
#   u'a_bidirectional',
#   u'bidirectional_reflectance',
#   u'reflectance_distribution',
#   u'distribution_function',
#   u'function_brdf',
#   u'brdf_may',
#   u'may_be',
#   u'be_required',
#   u'required_to',
#   u'to_characterize',
#   u'characterize_the',
#   u'the_scattering',
#   u'scattering_properties',
#   u'properties_of',
#   u'of_a',
#   u'a_surface',
#   u'surface_accurately',
#   u'accurately_although',
#   u'although_the',
#   u'the_albedo',
#   u'albedo_is',
#   u'is_a',
#   u'a_very',
#   u'very_useful',
#   u'useful_first',
#   u'first_approximationthe',
#   u'approximationthe_albedo',
#   u'albedo_is',
#   u'is_an',
#   u'an_important',
#   u'important_concept',
#   u'concept_in',
#   u'in_climatology',
#   u'climatology_and',
#   u'and_astronomy',
#   u'astronomy_as',
#   u'as_well',
#   u'well_as',
#   u'as_in',
#   u'in_calculating',
#   u'calculating_reflectivity',
#   u'reflectivity_of',
#   u'of_surfaces',
#   u'surfaces_in',
#   u'in_leed',
#   u'leed_sustainable',
#   u'sustainable_rating',
#   u'rating_systems',
#   u'systems_for',
#   u'for_buildings',
#   u'buildings_the',
#   u'the_average',
#   u'average_overall',
#   u'overall_albedo',
#   u'albedo_of',
#   u'of_earth',
#   u'earth_its',
#   u'its_planetary',
#   u'planetary_albedo',
#   u'albedo_is',
#   u'is_30',
#   u'30_to',
#   u'to_35',
#   u'35_because',
#   u'because_of',
#   u'of_the',
#   u'the_covering',
#   u'covering_by',
#   u'by_clouds',
#   u'clouds_but',
#   u'but_varies',
#   u'varies_widely',
#   u'widely_locally',
#   u'locally_across',
#   u'across_the',
#   u'the_surface',
#   u'surface_depending',
#   u'depending_on',
#   u'on_the',
#   u'the_geological',
#   u'geological_and',
#   u'and_environmental',
#   u'environmental_features',
#   u'features_the',
#   u'the_term',
#   u'term_was',
#   u'was_introduced',
#   u'introduced_into',
#   u'into_optics',
#   u'optics_by',
#   u'by_johann',
#   u'johann_heinrich',
#   u'heinrich_lambert',
#   u'lambert_in',
#   u'in_his',
#   u'his_1760',
#   u'1760_work',
#   u'work_photometria',
#   u'photometria_terrestrial',
#   u'terrestrial_albedo',
#   u'albedo_sample',
#   u'sample_albedos',
#   u'albedos_surface',
#   u'surface_typical',
#   u'typical_albedo',
#   u'albedo_fresh',
#   u'fresh_asphalt',
#   u'asphalt_004',
#   u'004_worn',
#   u'worn_asphalt',
#   u'asphalt_012',
#   u'012_conifer',
#   u'conifer_forest',
#   u'forest_summer',
#   u'summer_008',
#   u'008_009',
#   u'009_to',
#   u'to_015',
#   u'015_deciduous',
#   u'deciduous_trees',
#   u'trees_015',
#   u'015_to',
#   u'to_018',
#   u'018_bare',
#   u'bare_soil',
#   u'soil_017',
#   u'017_green',
#   u'green_grass',
#   u'grass_025',
#   u'025_desert',
#   u'desert_sand',
#   u'sand_040',
#   u'040_new',
#   u'new_concrete',
#   u'concrete_055',
#   u'055_ocean',
#   u'ocean_ice',
#   u'ice_0507',
#   u'0507_fresh',
#   u'fresh_snow',
#   u'snow_080090',
#   u'080090_albedos',
#   u'albedos_of',
#   u'of_typical',
#   u'typical_materials',
#   u'materials_in',
#   u'in_visible',
#   u'visible_light',
#   u'light_range',
#   u'range_from',
#   u'from_up',
#   u'up_to',
#   u'to_09',
#   u'09_for',
#   u'for_fresh',
#   u'fresh_snow',
#   u'snow_to',
#   u'to_about',
#   u'about_004',
#   u'004_for',
#   u'for_charcoal',
#   u'charcoal_one',
#   u'one_of',
#   u'of_the',
#   u'the_darkest',
#   u'darkest_substances',
#   u'substances_deeply',
#   u'deeply_shadowed',
#   u'shadowed_cavities',
#   u'cavities_can',
#   u'can_achieve',
#   u'achieve_an',
#   u'an_effective',
#   u'effective_albedo',
#   u'albedo_approaching',
#   u'approaching_the',
#   u'the_zero',
#   u'zero_of',
#   u'of_a',
#   u'a_black',
#   u'black_body',
#   u'body_when',
#   u'when_seen',
#   u'seen_from',
#   u'from_a',
#   u'a_distance',
#   u'distance_the',
#   u'the_ocean',
#   u'ocean_surface',
#   u'surface_has',
#   u'has_a',
#   u'a_low',
#   u'low_albedo',
#   u'albedo_as',
#   u'as_do',
#   u'do_most',
#   u'most_forests',
#   u'forests_whereas',
#   u'whereas_desert',
#   u'desert_areas',
#   u'areas_have',
#   u'have_some',
#   u'some_of',
#   u'of_the',
#   u'the_highest',
#   u'highest_albedos',
#   u'albedos_among',
#   u'among_landforms',
#   u'landforms_most',
#   u'most_land',
#   u'land_areas',
#   u'areas_are',
#   u'are_in',
#   u'in_an',
#   u'an_albedo',
#   u'albedo_range',
#   u'range_of',
#   u'of_01',
#   u'01_to',
#   u'to_04',
#   u'04_the',
#   u'the_average',
#   u'average_albedo',
#   u'albedo_of',
#   u'of_the',
#   u'the_earth',
#   u'earth_is',
#   u'is_about',
#   u'about_03',
#   u'03_this',
#   u'this_is',
#   u'is_far',
#   u'far_higher',
#   u'higher_than',
#   u'than_for',
#   u'for_the',
#   u'the_ocean',
#   u'ocean_primarily',
#   u'primarily_because',
#   u'because_of',
#   u'of_the',
#   u'the_contribution',
#   u'contribution_of',
#   u'of_cloudshuman',
#   u'cloudshuman_activities',
#   u'activities_have',
#   u'have_changed',
#   u'changed_the',
#   u'the_albedo',
#   u'albedo_via',
#   u'via_forest',
#   u'forest_clearance',
#   u'clearance_and',
#   u'and_farming',
#   u'farming_for',
#   u'for_example',
#   u'example_of',
#   u'of_various',
#   u'various_areas',
#   u'areas_around',
#   u'around_the',
#   u'the_globe',
#   u'globe_however',
#   u'however_quantification',
#   u'quantification_of',
#   u'of_this',
#   u'this_effect',
#   u'effect_on',
#   u'on_the',
#   u'the_global',
#   u'global_scale',
#   u'scale_is',
#   u'is_difficultthe',
#   u'difficultthe_classic',
#   u'classic_example',
#   u'example_of',
#   u'of_albedo',
#   u'albedo_effect',
#   u'effect_is',
#   u'is_the',
#   u'the_snowtemperature',
#   u'snowtemperature_feedback',
#   u'feedback_if',
#   u'if_a',
#   u'a_snowcovered',
#   u'snowcovered_area',
#   u'area_warms',
#   u'warms_and',
#   u'and_the',
#   u'the_snow',
#   u'snow_melts',
#   u'melts_the',
#   u'the_albedo',
#   u'albedo_decreases',
#   u'decreases_more',
#   u'more_sunlight',
#   u'sunlight_is',
#   u'is_absorbed',
#   u'absorbed_and',
#   u'and_the',
#   u'the_temperature',
#   u'temperature_tends',
#   u'tends_to',
#   u'to_increase',
#   u'increase_the',
#   u'the_converse',
#   u'converse_is',
#   u'is_also',
#   u'also_true',
#   u'true_if',
#   u'if_snow',
#   u'snow_forms',
#   u'forms_a',
#   u'a_cooling',
#   u'cooling_cycle',
#   u'cycle_happens',
#   u'happens_the',
#   u'the_intensity',
#   u'intensity_of',
#   u'of_the',
#   u'the_albedo',
#   u'albedo_effect',
#   u'effect_depends',
#   u'depends_on',
#   u'on_the',
#   u'the_size',
#   u'size_of',
#   u'of_the',
#   u'the_change',
#   u'change_in',
#   u'in_albedo',
#   u'albedo_and',
#   u'and_the',
#   u'the_amount',
#   u'amount_of',
#   u'of_insolation',
#   u'insolation_for',
#   u'for_this',
#   u'this_reason',
#   u'reason_it',
#   u'it_can',
#   u'can_be',
#   u'be_potentially',
#   u'potentially_very',
#   u'very_large',
#   u'large_in',
#   u'in_the',
#   u'the_tropics',
#   u'tropics_the',
#   u'the_earths',
#   u'earths_surface',
#   u'surface_albedo',
#   u'albedo_is',
#   u'is_regularly',
#   u'regularly_estimated',
#   u'estimated_via',
#   u'via_earth',
#   u'earth_observation',
#   u'observation_satellite',
#   u'satellite_sensors',
#   u'sensors_such',
#   u'such_as',
#   u'as_nasas',
#   u'nasas_modis',
#   u'modis_instruments',
#   u'instruments_on',
#   u'on_board',
#   u'board_the',
#   u'the_terra',
#   u'terra_and',
#   u'and_aqua',
#   u'aqua_satellites',
# ...
#   u'the_state',
#   u'state_transitioned',
#   u'transitioned_from',
#   u'from_one',
#   u'one_primarily',
#   u'primarily_based',
#   u'based_on',
#   u'on_agriculture',
#   u'agriculture_to',
#   u'to_one',
#   u'one_with',
#   u'with_diversified',
#   u'diversified_interests',
#   u'interests_the',
#   u'the_establishment',
#   u'establishment_or',
#   u'or_expansion',
#   u'expansion_of',
#   u'of_multiple',
#   u'multiple_united',
#   u'united_states',
#   u'states_armed',
#   u'armed_forces',
#   u'forces_installations',
#   u'installations_added',
#   u'added_to',
#   u'to_the',
#   u'the_state',
#   u'state_economy',
#   u'economy_and',
#   u'and_helped',
#   u'helped_bridge',
#   u'bridge_the',
#   u'the_gap',
#   u'gap_between',
#   u'between_an',
#   u'an_agricultural',
#   u'agricultural_and',
#   u'and_industrial',
#   u'industrial_economy',
#   u'economy_during',
#   u'during_the',
#   u'the_mid20th',
#   u'mid20th_century',
#   u'century_the',
#   u'the_state',
#   u'state_economy',
#   u'economy_in',
#   u'in_the',
#   u'the_21st',
#   u'21st_century',
#   u'century_is',
#   u'is_dependent',
#   u'dependent_on',
#   u'on_management',
#   u'management_automotive',
#   u'automotive_finance',
#   u'finance_manufacturing',
#   u'manufacturing_aerospace',
#   u'aerospace_mineral',
#   u'mineral_extraction',
#   u'extraction_healthcare',
#   u'healthcare_education',
#   u'education_retail',
#   u'retail_and',
#   u'and_technology',
#   u'technology_alabama',
#   u'alabama_is',
#   u'is_unofficially',
#   u'unofficially_nicknamed',
#   u'nicknamed_the',
#   u'the_yellowhammer',
#   u'yellowhammer_state',
#   u'state_after',
#   u'after_the',
#   u'the_state',
#   u'state_bird',
#   u'bird_alabama',
#   u'alabama_is',
#   u'is_also',
#   u'also_known',
#   u'known_as',
#   u'as_the',
#   u'the_heart',
#   u'heart_of',
#   u'of_dixie',
#   u'dixie_the',
#   u'the_state',
#   u'state_tree',
#   u'tree_is',
#   u'is_the',
#   u'the_longleaf',
#   u'longleaf_pine',
#   u'pine_the',
#   u'the_state',
#   u'state_flower',
#   u'flower_is',
#   u'is_the',
#   u'the_camellia',
#   u'camellia_the',
#   u'the_capital',
#   u'capital_of',
#   u'of_alabama',
#   u'alabama_is',
#   u'is_montgomery',
#   u'montgomery_the',
#   u'the_largest',
#   u'largest_city',
#   u'city_by',
#   u'by_population',
#   u'population_is',
#   u'is_birmingham',
#   u'birmingham_the',
#   u'the_largest',
#   u'largest_city',
#   u'city_by',
#   u'by_total',
#   u'total_land',
#   u'land_area',
#   u'area_is',
#   u'is_huntsville',
#   u'huntsville_the',
#   u'the_oldest',
#   u'oldest_city',
#   u'city_is',
#   u'is_mobile',
#   u'mobile_founded',
#   u'founded_by',
#   u'by_french',
#   u'french_colonists',
#   u'colonists_thomason',
#   u'thomason_michael',
#   u'michael_mobile',
#   u'mobile_the',
#   u'the_new',
#   u'new_history',
#   u'history_of',
#   u'of_alabamas',
#   u'alabamas_first',
#   u'first_citypages',
#   u'citypages_221',
#   u'221_tuscaloosa',
#   u'tuscaloosa_university',
#   u'university_of',
#   u'of_alabama',
#   u'alabama_press',
#   u'press_2001',
#   u'2001_isbn',
#   u'isbn_0817310657',
#   u'0817310657_history',
#   u'history_etymologythe',
#   u'etymologythe_alabama',
#   u'alabama_people',
#   u'people_a',
#   u'a_muskogeanspeaking',
#   u'muskogeanspeaking_tribe',
#   u'tribe_whose',
#   u'whose_members',
#   u'members_lived',
#   u'lived_just',
#   u'just_below',
#   u'below_the',
#   u'the_confluence',
#   u'confluence_of',
#   u'of_the',
#   u'the_coosa',
#   u'coosa_and',
#   u'and_tallapoosa',
#   u'tallapoosa_rivers',
#   u'rivers_on',
#   u'on_the',
#   u'the_upper',
#   u'upper_reaches',
#   u'reaches_of',
#   u'of_the',
#   u'the_alabama',
#   u'alabama_river',
#   u'river_served',
#   u'served_as',
#   u'as_the',
#   u'the_etymological',
#   u'etymological_source',
#   u'source_of',
#   u'of_the',
#   u'the_names',
#   u'names_of',
#   u'of_the',
#   u'the_river',
#   u'river_and',
#   u'and_state',
#   u'state_in',
#   u'in_the',
#   u'the_alabama',
#   u'alabama_language',
#   u'language_the',
#   u'the_word',
#   u'word_for',
#   u'for_an',
#   u'an_alabama',
#   u'alabama_person',
#   u'person_is',
#   u'is_albaamo',
#   u'albaamo_or',
#   u'or_variously',
#   u'variously_albaama',
#   u'albaama_or',
#   u'or_albamo',
#   u'albamo_in',
#   u'in_different',
#   u'different_dialects',
#   u'dialects_the',
#   u'the_plural',
#   u'plural_form',
#   u'form_alabama',
#   u'alabama_persons',
#   u'persons_is',
#   u'is_albaamaha',
#   u'albaamaha_the',
#   u'the_word',
#   u'word_alabama',
#   u'alabama_is',
#   u'is_believed',
#   u'believed_to',
#   u'to_have',
#   u'have_originated',
#   u'originated_from',
#   u'from_the',
#   u'the_choctaw',
#   u'choctaw_language',
#   u'language_and',
#   u'and_was',
#   u'was_later',
#   u'later_adopted',
#   u'adopted_by',
#   u'by_the',
#   u'the_alabama',
#   u'alabama_tribe',
#   u'tribe_as',
#   u'as_their',
#   u'their_name',
#   u'name_the',
#   u'the_spelling',
#   u'spelling_of',
#   u'of_the',
#   u'the_word',
#   u'word_varies',
#   u'varies_significantly',
#   u'significantly_between',
#   u'between_sources',
#   u'sources_the',
#   u'the_first',
#   u'first_usage',
#   u'usage_appears',
#   u'appears_in',
#   u'in_three',
#   u'three_accounts',
#   u'accounts_of',
#   u'of_the',
#   u'the_hernando',
#   u'hernando_de',
#   u'de_soto',
#   u'soto_expedition',
#   u'expedition_of',
#   u'of_1540',
#   u'1540_with',
#   u'with_garcilasso',
#   u'garcilasso_de',
#   u'de_la',
#   u'la_vega',
#   u'vega_using',
#   u'using_alibamo',
#   u'alibamo_while',
#   u'while_the',
#   u'the_knight',
#   u'knight_of',
#   u'of_elvas',
#   u'elvas_and',
#   u'and_rodrigo',
#   u'rodrigo_ranjel',
#   u'ranjel_wrote',
#   u'wrote_alibamu',
#   u'alibamu_and',
#   u'and_limamu',
#   u'limamu_respectively',
#   u'respectively_as',
#   u'as_early',
#   u'early_as',
#   u'as_1702',
#   u'1702_the',
#   u'the_tribe',
#   u'tribe_was',
#   u'was_known',
#   u'known_to',
#   u'to_the',
#   u'the_french',
#   u'french_as',
#   u'as_alibamon',
#   u'alibamon_with',
#   u'with_french',
#   u'french_maps',
#   u'maps_identifying',
#   u'identifying_the',
#   u'the_river',
#   u'river_as',
#   u'as_rivire',
#   u'rivire_des',
#   u'des_alibamons',
#   u'alibamons_other',
#   u'other_spellings',
#   u'spellings_of',
#   u'of_the',
#   u'the_appellation',
#   u'appellation_have',
#   u'have_included',
#   u'included_alibamu',
#   u'alibamu_alabamo',
#   u'alabamo_albama',
#   u'albama_alebamon',
#   u'alebamon_alibama',
#   u'alibama_alibamou',
#   u'alibamou_alabamu',
#   u'alabamu_and',
#   u'and_allibamou',
#   u'allibamou_the',
#   u'the_use',
#   u'use_of',
#   u'of_state',
#   u'state_names',
#   u'names_derived',
#   u'derived_from',
#   u'from_native',
#   u'native_american',
#   u'american_languages',
#   u'languages_is',
#   u'is_common',
#   u'common_an',
#   u'an_estimated',
#   u'estimated_27states',
#   u'27states_have',
#   u'have_names',
#   u'names_of',
#   u'of_native',
#   u'native_american',
#   u'american_origin',
#   u'origin_although',
#   u'although_the',
#   u'the_origin',
#   u'origin_of',
#   u'of_alabama',
#   u'alabama_could',
#   u'could_be',
#   u'be_discerned',
#   u'discerned_sources',
#   u'sources_disagree',
#   u'disagree_on',
#   u'on_its',
#   u'its_meaning',
#   u'meaning_an',
#   u'an_1842',
#   u'1842_article',
#   u'article_in',
#   u'in_the',
#   u'the_jacksonville',
#   u'jacksonville_republican',
#   u'republican_originated',
#   u'originated_the',
#   u'the_idea',
#   u'idea_that',
#   u'that_the',
#   u'the_meaning',
#   u'meaning_was',
#   u'was_here',
#   u'here_we',
#   u'we_rest',
#   u'rest_this',
#   u'this_notion',
#   u'notion_was',
#   u'was_popularized',
#   u'popularized_in',
#   u'in_the',
#   u'the_1850s',
#   u'1850s_through',
#   u'through_the',
#   u'the_writings',
#   u'writings_of',
#   u'of_alexander',
#   u'alexander_beaufort',
#   u'beaufort_meek',
#   u'meek_experts',
#   u'experts_in',
#   u'in_the',
#   u'the_muskogean',
#   u'muskogean_languages',
#   u'languages_have',
#   u'have_been',
#   u'been_unable',
#   u'unable_to',
#   u'to_find',
#   u'find_any',
#   u'any_evidence',
#   u'evidence_to',
#   u'to_support',
#   u'support_such',
#   u'such_a',
#   u'a_translation',
#   u'translation_scholars',
#   u'scholars_believe',
#   u'believe_the',
#   u'the_word',
#   u'word_comes',
#   u'comes_from',
#   u'from_the',
#   u'the_choctaw',
#   u'choctaw_alba',
#   u'alba_meaning',
#   u'meaning_plants',
#   u'plants_or',
#   u'or_weeds',
#   u'weeds_and',
#   u'and_amo',
#   u'amo_meaning',
#   u'meaning_to',
#   u'to_cut',
#   u'cut_to',
#   u'to_trim',
#   u'trim_or',
#   u'or_to',
#   u'to_gather',
#   u'gather_the',
#   u'the_meaning',
#   u'meaning_may',
#   u'may_have',
#   u'have_been',
#   u'been_clearers',
#   u'clearers_of',
#   u'of_the',
#   u'the_thicket',
#   u'thicket_or',
#   u'or_herb',
#   u'herb_gatherers',
#   u'gatherers_which',
#   u'which_may',
#   u'may_refer',
#   u'refer_to',
#   u'to_clearing',
#   u'clearing_of',
#   u'of_land',
#   u'land_for',
#   u'for_cultivation',
#   u'cultivation_or',
#   u'or_to',
#   u'to_collecting',
#   u'collecting_medicinal',
#   u'medicinal_plants',
#   u'plants_alabama',
#   u'alabama_is',
#   u'is_but',
#   u'but_one',
#   u'one_of',
#   u'of_many',
#   u'many_place',
#   u'place_names',
#   u'names_in',
#   u'in_the',
#   u'the_state',
#   u'state_of',
#   u'of_native',
#   u'native_american',
#   u'american_origin',
#   u'origin_preeuropean',
#   u'preeuropean_settlement',
#   u'settlement_indigenous',
#   u'indigenous_peoples',
#   u'peoples_of',
#   u'of_varying',
#   u'varying_cultures',
#   u'cultures_lived',
#   u'lived_in',
#   u'in_the',
#   u'the_area',
#   u'area_for',
#   u'for_thousands',
#   u'thousands_of',
#   u'of_years',
#   u'years_before',
#   u'before_european',
#   u'european_colonization',
#   u'colonization_trade',
#   u'trade_with',
#   u'with_the',
#   u'the_northeast',
#   u'northeast_via',
#   u'via_the',
#   u'the_ohio',
#   u'ohio_river',
#   u'river_began',
#   u'began_during',
#   u'during_the',
#   u'the_burial',
#   u'burial_mound',
#   u'mound_period',
#   u'period_1000bcad700',
#   u'1000bcad700_and',
#   u'and_continued',
#   u'continued_until',
#   u'until_european',
#   u'european_contact',
#   u'contact_the',
#   u'the_agrarian',
#   u'agrarian_mississippian',
#   u'mississippian_culture',
#   u'culture_covered',
#   u'covered_most',
#   u'most_of',
#   u'of_the',
#   u'the_state',
#   u'state_from',
#   u'from_ad',
#   u'ad_1000',
#   u'1000_to',
#   u'to_1600',
#   u'1600_with',
#   u'with_one',
#   u'one_of',
#   u'of_its',
#   u'its_major',
#   u'major_centers',
#   u'centers_being',
#   u'being_at',
#   u'at_the',
#   u'the_moundville',
#   u'moundville_archaeological',
#   u'archaeological_site',
#   u'site_in',
#   u'in_moundville',
#   u'moundville_alabama',
#   u'alabama_analysis',
#   u'analysis_of',
#   u'of_artifacts',
#   u'artifacts_recovered',
#   u'recovered_from',
#   u'from_archaeological',
#   u'archaeological_excavations',
#   u'excavations_at',
#   u'at_moundville',
#   u'moundville_were',
#   u'were_the',
#   u'the_basis',
#   u'basis_of',
#   u'of_scholars',
#   u'scholars_formulating',
#   u'formulating_the',
#   u'the_characteristics',
#   u'characteristics_of',
#   u'of_the',
#   u'the_southeastern',
#   u'southeastern_ceremonial',
#   u'ceremonial_complex',
#   u'complex_secc',
#   u'secc_contrary',
#   u'contrary_to',
#   u'to_popular',
#   u'popular_belief',
#   u'belief_the',
#   u'the_secc',
#   u'secc_appears',
#   u'appears_to',
#   u'to_have',
#   u'have_no',
#   u'no_direct',
#   u'direct_links',
#   u'links_to',
#   u'to_mesoamerican',
#   u'mesoamerican_culture',
#   u'culture_but',
#   u'but_developed',
#   u'developed_independently',
#   u'independently_the',
#   u'the_ceremonial',
#   u'ceremonial_complex',
#   u'complex_represents',
#   u'represents_a',
#   u'a_major',
#   u'major_component',
#   u'component_of',
#   u'of_the',
#   u'the_religion',
#   u'religion_of',
#   u'of_the',
#   u'the_mississippian',
#   u'mississippian_peoples',
#   u'peoples_it',
#   u'it_is',
#   u'is_one',
#   u'one_of',
#   u'of_the',
#   u'the_primary',
#   u'primary_means',
#   u'means_by',
#   u'by_which',
#   u'which_their',
#   u'their_religion',
#   u'religion_is',
#   u'is_understood',
#   u'understood_among',
#   u'among_the',
#   u'the_historical',
#   u'historical_tribes',
#   u'tribes_of',
#   u'of_native',
#   u'native_american',
#   u'american_people',
#   u'people_living',
#   u'living_in',
#   u'in_the',
#   u'the_area',
#   u'area_of',
#   u'of_presentday',
#   u'presentday_alabama',
#   u'alabama_at',
#   u'at_the',
#   u'the_time',
#   u'time_of',
#   u'of_european',
#   u'european_contact',
#   u'contact_were',
#   u'were_iroquoianspeaking',
#   u'iroquoianspeaking_cherokee',
#   u'cherokee_and',
#   u'and_the',
#   u'the_muskogeanspeaking',
#   u'muskogeanspeaking_alabama',
#   u'alabama_alibamu',
#   u'alibamu_chickasaw',
#   u'chickasaw_choctaw',
#   u'choctaw_creek',
#   u'creek_and',
#   u'and_koasati',
#   u'koasati_european',
#   u'european_settlementthe',
#   u'settlementthe_french',
#   u'french_founded',
#   u'founded_the',
#   u'the_first',
#   u'first_european',
#   u'european_settlement',
#   u'settlement_in',
#   u'in_the',
#   u'the_region',
#   u'region_at',
#   u'at_old',
#   u'old_mobile',
#   u'mobile_in',
#   u'in_1702',
#   u'1702_the',
#   u'the_city',
#   u'city_was',
#   u'was_moved',
#   u'moved_to',
#   u'to_the',
#   u'the_current',
#   u'current_site',
#   u'site_of',
#   u'of_mobile',
#   u'mobile_in',
#   u'in_1711',
#   u'1711_this',
#   u'this_area',
#   u'area_was',
#   u'was_french',
#   u'french_from',
#   u'from_1702',
#   u'1702_to',
#   u'to_1763',
#   u'1763_part',
#   u'part_of',
#   u'of_british',
#   u'british_west',
#   u'west_florida',
#   u'florida_from',
#   u'from_1763',
#   u'1763_to',
#   u'to_1783',
#   u'1783_and',
#   u'and_split',
#   u'split_between',
#   u'between_the',
#   u'the_united',
#   u'united_states',
#   u'states_and',
#   u'and_spain',
#   u'spain_from',
#   u'from_1783',
#   u'1783_to',
#   u'to_1821',
#   u'1821_thomas',
#   u'thomas_bassett',
#   u'bassett_a',
#   u'a_loyalist',
#   u'loyalist_to',
#   u'to_the',
#   u'the_british',
#   u'british_monarchy',
#   u'monarchy_was',
#   u'was_one',
#   u'one_of',
#   u'of_the',
#   u'the_earliest',
#   u'earliest_white',
#   u'white_settlers',
#   u'settlers_in',
#   u'in_the',
#   u'the_state',
#   u'state_outside',
#   u'outside_of',
#   u'of_the',
#   u'the_mobile',
#   u'mobile_area',
#   u'area_he',
#   u'he_settled',
#   u'settled_in',
#   u'in_the',
#   u'the_tombigbee',
#   u'tombigbee_settlements',
#   u'settlements_in',
#   u'in_what',
#   u'what_is',
#   u'is_now',
#   u'now_washington',
#   u'washington_county',
#   u'county_during',
#   u'during_the',
#   u'the_early',
#   u'early_1770s',
#   u'1770s_what',
#   u'what_is',
#   u'is_now',
#   u'now_the',
#   u'the_counties',
#   u'counties_of',
#   u'of_baldwin',
#   u'baldwin_and',
#   u'and_mobile',
#   u'mobile_became',
#   u'became_part',
#   u'part_of',
#   u'of_spanish',
#   u'spanish_west',
#   u'west_florida',
#   u'florida_in',
#   u'in_1783',
#   u'1783_part',
#   u'part_of',
#   u'of_the',
#   u'the_independent',
#   u'independent_republic',
#   u'republic_of',
#   u'of_west',
#   u'west_florida',
#   u'florida_in',
#   u'in_1810',
#   u'1810_and',
#   u'and_was',
#   u'was_finally',
#   u'finally_added',
#   u'added_to',
#   u'to_the',
#   u'the_mississippi',
#   u'mississippi_territory',
#   u'territory_in',
#   u'in_1812',
#   u'1812_the',
#   u'the_area',
#   u'area_making',
#   u'making_up',
#   u'up_todays',
#   u'todays_northern',
#   u'northern_and',
#   u'and_central',
#   u'central_alabama',
#   u'alabama_and',
#   u'and_mississippi',
#   u'mississippi_then',
#   u'then_known',
#   u'known_as',
#   u'as_the',
#   u'the_yazoo',
#   u'yazoo_lands',
#   u'lands_had',
#   u'had_been',
#   u'been_claimed',
#   u'claimed_by',
#   u'by_the',
#   u'the_province',
#   u'province_of',
#   u'of_georgia',
#   u'georgia_after',
#   u'after_1767',
#   u'1767_following',
#   u'following_the',
#   u'the_revolutionary',
#   u'revolutionary_war',
#   u'war_it',
#   u'it_remained',
#   u'remained_a',
#   u'a_part',
#   u'part_of',
#   u'of_georgia',
#   u'georgia_although',
#   u'although_heavily',
#   u'heavily_disputed',
#   u'disputed_with',
#   u'with_the',
#   u'the_exception',
#   u'exception_of',
#   u'of_the',
#   u'the_immediate',
#   u'immediate_area',
#   u'area_around',
#   u'around_mobile',
#   u'mobile_and',
#   u'and_the',
#   u'the_yazoo',
#   u'yazoo_lands',
#   u'lands_what',
#   u'what_is',
#   u'is_now',
#   u'now_central',
#   u'central_alabama',
#   u'alabama_was',
#   u'was_made',
#   u'made_part',
#   u'part_of',
#   u'of_the',
#   u'the_mississippi',
#   u'mississippi_territory',
#   u'territory_upon',
#   u'upon_its',
#   u'its_creation',
#   u'creation_in',
#   u'in_1798',
#   u'1798_the',
#   u'the_yazoo',
#   u'yazoo_lands',
#   u'lands_were',
#   u'were_added',
#   u'added_to',
#   u'to_the',
#   u'the_territory',
#   u'territory_in',
#   u'in_1804',
#   u'1804_following',
#   u'following_the',
#   u'the_yazoo',
#   u'yazoo_land',
#   u'land_scandal',
#   u'scandal_spain',
#   u'spain_had',
#   u'had_kept',
#   u'kept_a',
#   u'a_governmental',
#   u'governmental_presence',
#   u'presence_in',
#   u'in_mobile',
#   u'mobile_after',
#   u'after_1812',
#   u'1812_when',
#   u'when_andrew',
#   u'andrew_jacksons',
#   u'jacksons_forces',
#   ...]]

# %%
# берем биграммы, начинающиеся со слова narodnaya
filtered_bigrams = bigrams.flatMap(lambda x: [word for word in x if word.startswith('narodnaya')])

# %%
filtered_bigrams.take(5)
# Out:
# [u'narodnaya_volya',
#  u'narodnaya_volya',
#  u'narodnaya_volya',
#  u'narodnaya_volya',
#  u'narodnaya_volya']

# %%
# подсчитываем число вхождений биграмм 
grouped_bigrams = filtered_bigrams.map(lambda x: (x, 1)).reduceByKey(lambda x, y: x + y).collect()

# %%
grouped_bigrams
# Out:
# [(u'narodnaya_gazeta', 1), (u'narodnaya_volya', 9)]

# %%
# вывод в лексикографическом порядке
for key, value in sorted(grouped_bigrams, key=lambda x: x[0]):
    print key, '\t', value
# Out:
# narodnaya_gazeta 	1
# narodnaya_volya 	9

# %% [markdown]
# # Задача #2: коллокации

# %% [markdown]
# ### 2.1 Подготовка RDD

# %%
# бродкастим словарь со стоп-словами
br_stop_words = sc.broadcast(stop_words)

# %%
# удаляем стоп-слова из списков слов, полученных из каждой статьи
filtered_lists = articles_to_list.map(lambda x: [word for word in x if word not in br_stop_words.value])

# %%
# получаем биграммы из отфильтрованного списка слов
upd_bigrams = filtered_lists.flatMap(lambda x: list(bigram(x)))

# %%
# подсчитываем число вхождений биграмм 
grouped_bigrams = upd_bigrams.map(lambda x: (x, 1))\
                             .reduceByKey(lambda x, y: x + y)

# %%
# берем только те биграммы, которые встречались более 500 раз 
frequent_bigrams = grouped_bigrams.filter(lambda x: x[1] >= 500)

# %%
frequent_bigrams.take(5)
# Out:
# [(u'soviet_union', 844),
#  (u'catholic_church', 575),
#  (u'american_baseball', 603),
#  (u'united_nations', 695),
#  (u'american_actor', 1092)]

# %% [markdown]
# ### 2.2. NPMI

# %% [markdown]
# Общее кол-во слов в тексте

# %%
flat_words = filtered_lists.flatMap(lambda x: x)

# %%
flat_words.take(5)
# Out:
# [u'anarchism', u'anarchism', u'defined', u'political', u'philosophy']

# %%
total_number_of_words = flat_words.count()

# %%
total_number_of_words
# Out:
# 6848907

# %%
total_number_of_words = sc.broadcast(total_number_of_words)

# %%
word_count = flat_words.map(lambda x: (x, 1)).reduceByKey(lambda x, y: x + y)

# %%
word_count.take(5)
# Out:
# [(u'biennials', 10),
#  (u'tripolitan', 2),
#  (u'vexillifera', 1),
#  (u'refreshable', 9),
#  (u'capitaltheir', 1)]

# %%
# вероятность увидеть слово “a” в датасете
p_a = word_count.map(lambda x: (x[0], float(x[1])/total_number_of_words.value)).cache()

# %%
p_a.take(5)
# Out:
# [(u'biennials', 1.4600869890626344e-06),
#  (u'tripolitan', 2.9201739781252686e-07),
#  (u'vexillifera', 1.4600869890626343e-07),
#  (u'refreshable', 1.314078290156371e-06),
#  (u'nunnery', 7.300434945313172e-07)]

# %% [markdown]
# Общее кол-во пар слов в тексте

# %%
total_number_of_pairs = upd_bigrams.count()

# %%
total_number_of_pairs
# Out:
# 6844807

# %%
total_number_of_pairs = sc.broadcast(total_number_of_pairs)

# %%
# вероятность увидеть пару слов “a” и “b”, идущих подряд
p_ab = frequent_bigrams.map(lambda x: (x[0], float(x[1])/total_number_of_pairs.value)).cache()

# %%
p_ab.take(5)
# Out:
# [(u'soviet_union', 0.00012330515674145379),
#  (u'catholic_church', 8.40052904340473e-05),
#  (u'american_baseball', 8.80959828377922e-05),
#  (u'united_nations', 0.00010153682930723978),
#  (u'american_actor', 0.00015953700374605158)]

# %%
p_ab.count()
# Out:
# 38

# %% [markdown]
# Расчет по формуле:
# $$ PMI(a,b) = ln( \dfrac{P(ab)}{P(a) * P(b)}) $$
#
# $$ NPMI(a,b) = \dfrac{PMI(a,b)}{-ln(P(ab))} $$

# %%
part_1 = p_ab.map(lambda x: (x[0].split('_')[0], x))\
             .join(p_a)

# %%
part_1.take(5)
# Out:
# [(u'soviet',
#   ((u'soviet_union', 0.00012330515674145379), 0.0003442885120209692)),
#  (u'civil', ((u'civil_war', 0.00014492738801839117), 0.000366335825555815)),
#  (u'references',
#   ((u'references_reading', 7.567780946928087e-05), 0.0005938173784517733)),
#  (u'references',
#   ((u'references_external', 0.0001823280042812018), 0.0005938173784517733)),
#  (u'high', ((u'high_school', 9.11640021406009e-05), 0.0008509386972257034))]

# %%
part_2 = part_1.map(lambda x: (x[1][0][0].split('_')[1], x[1]))\
             .join(p_a)

# %%
part_2.take(5)
# Out:
# [(u'union',
#   (((u'soviet_union', 0.00012330515674145379), 0.0003442885120209692),
#    0.0005089863243872343)),
#  (u'zealand',
#   (((u'new_zealand', 0.00011921446433770887), 0.0027582503310382227),
#    0.0001242534027692302)),
#  (u'africa',
#   (((u'south_africa', 8.502796353498353e-05), 0.0008728400020616428),
#    0.00029128735431799556)),
#  (u'force',
#   (((u'air_force', 0.00016581913850894554), 0.0006390800751127151),
#    0.0005593593255098952)),
#  (u'states',
#   (((u'united_states', 0.0009579525032626925), 0.0014228547708415372),
#    0.0015018454769498257))]

# %%
# x[1][0][0][0] - bigramm
# x[1][0][0][1] - P(ab)
# x[1][0][1] - P(a)
# x[1][1] - P(b)

part_3 = part_2.map(lambda x: (x[1][0][0][0], log(x[1][0][0][1]/(x[1][0][1]*x[1][1]))/(-log(x[1][0][0][1]))))\
               .collect()

# %%
part_3[:5]
# Out:
# [(u'soviet_union', 0.7284059680131149),
#  (u'new_zealand', 0.6477064337046002),
#  (u'south_africa', 0.6201557097970846),
#  (u'university_press', 0.688645571160978),
#  (u'air_force', 0.7053256101735037)]

# %%
TOP = 39

for key, value in sorted(part_3, key=lambda x: x[1], reverse=True)[:TOP]:
    print key, '\t', round(value, 3)
# Out:
# los_angeles 	0.972
# external_links 	0.949
# prime_minister 	0.884
# united_states 	0.878
# san_francisco 	0.852
# new_york 	0.787
# supreme_court 	0.775
# 19th_century 	0.757
# 20th_century 	0.751
# references_external 	0.732
# soviet_union 	0.728
# air_force 	0.705
# baseball_player 	0.692
# university_press 	0.689
# united_kingdom 	0.684
# roman_catholic 	0.683
# references_reading 	0.669
# notes_references 	0.661
# award_best 	0.661
# north_america 	0.653
# new_zealand 	0.648
# civil_war 	0.64
# catholic_church 	0.625
# world_war 	0.621
# south_africa 	0.62
# war_ii 	0.617
# took_place 	0.613
# roman_empire 	0.61
# united_nations 	0.593
# american_singersongwriter 	0.565
# high_school 	0.564
# american_actor 	0.559
# american_actress 	0.54
# american_baseball 	0.513
# york_city 	0.491
# american_football 	0.481
# years_later 	0.414
# north_american 	0.379
